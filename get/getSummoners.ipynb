# %%
import pandas as pd

# %%
df=pd.read_json("./Bv saviox2w.json")

# %%
df.head()
# Out:
#         gameId platformId  gameCreation  gameDuration  queueId  mapId  \
# 0  889264115.0        LA1  1.593122e+12        1960.0    420.0   11.0
# 1  881255248.0        LA1  1.591861e+12        2054.0    420.0   11.0
# 2  881238984.0        LA1  1.591858e+12        2408.0    420.0   11.0
# 3  881234708.0        LA1  1.591855e+12        2683.0    420.0   11.0
# 4  881222110.0        LA1  1.591852e+12        2231.0    420.0   11.0
#
#    seasonId     gameVersion gameMode      gameType  \
# 0      13.0  10.13.325.7485  CLASSIC  MATCHED_GAME
# 1      13.0  10.12.324.5925  CLASSIC  MATCHED_GAME
# 2      13.0  10.12.324.5925  CLASSIC  MATCHED_GAME
# 3      13.0  10.12.324.5925  CLASSIC  MATCHED_GAME
# 4      13.0  10.12.324.5925  CLASSIC  MATCHED_GAME
#
#                                                teams  \
# 0  [{'teamId': 100, 'win': 'Win', 'firstBlood': T...
# 1  [{'teamId': 100, 'win': 'Fail', 'firstBlood': ...
# 2  [{'teamId': 100, 'win': 'Win', 'firstBlood': F...
# ...

# %%
players=pd.DataFrame()
aux=pd.json_normalize(df.participantIdentities.values[0])

# %%
players=players.append(aux)

# %%
aux=pd.json_normalize(df.participantIdentities.values[1])
players=players.append(aux)

# %%
players
# Out:
#    participantId player.platformId  \
# 0              1               LA1
# 1              2               LA1
# 2              3                NA
# 3              4               LA1
# 4              5               LA1
# 5              6               LA1
# 6              7               la1
# 7              8               LA1
# 8              9               LA1
# 9             10               LA1
# 0              1               NA1
# 1              2               LA1
# 2              3               LA1
# 3              4                NA
# 4              5               NA1
# 5              6               LA1
# 6              7               LA1
# 7              8               NA1
# 8              9               LA1
# 9             10               LA1
#
#                                     player.accountId player.summonerName  \
# 0    5Tcph8tnVn8dVu2boBrHpIh-9h-hC1o3YoEET8Nje7Ofxl4           chukyfluy
# ...

# %%
players=pd.DataFrame()
for i in range(len(df.participantIdentities.values)):
    if df.participantIdentities.values[i]==None:
        continue
    aux=pd.json_normalize(df.participantIdentities.values[i])
    players=players.append(aux)

# %%
players.drop_duplicates().reset_index(drop=True).to_csv("players.csv")
